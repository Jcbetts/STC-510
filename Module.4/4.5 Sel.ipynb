# %%
from selenium import webdriver
from time import sleep
from selenium.webdriver.chrome.options import Options
# import config.py -use this and place in gitignore when sending to github-

# %%
#Configuration file for STE 510 4.5
CHROMELOC = 'home/justin/'
UNAME = 'jcbetts@proton.me'
PASSWORD = 'qb)kc78T$DgAZjr@'

# %%
option = webdriver.ChromeOptions()
driver = webdriver.Chrome(options = option)

# %%
driver.get('https://sciences.social/auth/sign_in')
sleep(15)

# %%
log_form=driver.find_element(by='id', value='user_email').send_keys(UNAME)
sleep(15)

# %%
log_form=driver.find_element(by='id', value='user_password').send_keys(PASSWORD)
sleep(15)

# %%
log_in=driver.find_element(by='name', value='button').click()

# %%
pagesource = driver.page_source
print(pagesource)
# Out:
# <html lang="en" style="margin-right: 0px;"><head>
# <meta charset="utf-8">
# <meta content="width=device-width, initial-scale=1" name="viewport">
# <link href="https://cdn.masto.host" rel="dns-prefetch">
# <link href="/favicon.ico" rel="icon" type="image/x-icon">
# <link href="/packs/media/icons/favicon-16x16-c58fdef40ced38d582d5b8eed9d15c5a.png" rel="icon" sizes="16x16" type="image/png">
# <link href="/packs/media/icons/favicon-32x32-249409a6d9f300112c51af514d863112.png" rel="icon" sizes="32x32" type="image/png">
# <link href="/packs/media/icons/favicon-48x48-c1197e9664ee6476d2715a1c4293bf61.png" rel="icon" sizes="48x48" type="image/png">
# <link href="/packs/media/icons/apple-touch-icon-57x57-c9dca808280860c51d0357f6a3350f4d.png" rel="apple-touch-icon" sizes="57x57">
# <link href="/packs/media/icons/apple-touch-icon-60x60-bb247db195d9ee9d8c687b2b048508d9.png" rel="apple-touch-icon" sizes="60x60">
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 driver.get_screenshot_as_png('')
#
# TypeError: WebDriver.get_screenshot_as_png() takes 1 positional argument but 2 were given

# %%
driver.quit()
