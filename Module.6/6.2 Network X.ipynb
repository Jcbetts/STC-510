# %%
import networkx as nx

# %%
alice = nx.Graph()

# %%
alice.add_edge('Alice', 'Rabbit')
alice.add_edge('Alice', 'Cat')
alice.add_edge('Alice', 'Queen')
alice.add_edge('Alice', 'Caterpillar')
alice.add_edge('Alice', 'Hatter')
alice.add_edge('Alice', 'Hare')
alice.add_edge('Rabbit', 'Queen')
alice.add_edge('Hatter', 'Doormouse')
alice.add_edge('Hatter', 'Hare')
alice.add_edge('Hare', 'Doormouse')
alice.add_edge('Cat', 'Queen')

# %%
print(alice)
# Out:
# Graph with 9 nodes and 12 edges

# %%
nx.average_clustering(alice)
# Out:
# 0.5714285714285714

# %%
nx.shortest_path(alice, 'Caterpillar', 'Queen')
# Out:
# ['Caterpillar', 'Alice', 'Queen']

# %%
nx.betweenness_centrality(alice)
# Out:
# {'Alice': 0.8035714285714285,
#  'Rabbit': 0.0,
#  'Cat': 0.0,
#  'Queen': 0.017857142857142856,
#  'Caterpillar': 0.0,
#  'Hatter': 0.10714285714285714,
#  'Hare': 0.10714285714285714,
#  'Doormouse': 0.0,
#  '': 0.0}

# %%
nx.degree_centrality(alice)
# Out:
# {'Alice': 0.875,
#  'Rabbit': 0.25,
#  'Cat': 0.25,
#  'Queen': 0.375,
#  'Caterpillar': 0.125,
#  'Hatter': 0.375,
#  'Hare': 0.375,
#  'Doormouse': 0.25,
#  '': 0.125}

# %%
nx.eigenvector_centrality(alice)
# Out:
# {'Alice': 0.5983503098260725,
#  'Rabbit': 0.2868002088281446,
#  'Cat': 0.2868002088281446,
#  'Queen': 0.3532215076775266,
#  'Caterpillar': 0.1803408193866444,
#  'Hatter': 0.3488768955269882,
#  'Hare': 0.3488768955269882,
#  'Doormouse': 0.2103020564286819,
#  '': 0.1803408193866444}

# %%
nx.draw_networkx(alice)

# %%
nx.degreesof(alice, 'Hare', 'Alice')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [31], line 1
# ----> 1 nx.degreesof(alice, 'Hare', 'Alice')
#
# File /usr/lib/python3/dist-packages/networkx/__init__.py:51, in __getattr__(name)
#      42 if name == "write_yaml":
#      43     raise ImportError(
#      44         "\nwrite_yaml has been removed from NetworkX, please use `yaml`\n"
#      45         "directly:\n\n"
#    (...)
#      49         "This message will be removed in NetworkX 3.0."
#      50     )
# ---> 51 raise AttributeError(f"module {__name__} has no attribute {name}")
#
# AttributeError: module networkx has no attribute degreesof

# %%
len(nx.shortest_path(alice,'Hare','Alice'))-1
# Out:
# 1
