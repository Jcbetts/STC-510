# %%
import pandas as pd
import re
n = pd.read_csv('articles1.csv')
n.drop(columns='Unnamed: 0', inplace=True)
n
# Out:
#           id                                              title  \
# 0      17283  House Republicans Fret About Winning Their Hea...
# 1      17284  Rift Between Officers and Residents as Killing...
# 2      17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...      ...                                                ...
# 49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999  73469                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# 0      New York Times                     Carl Hulse  2016-12-31  2016.0
# ...

# %%
n[n.publication=='New York Times']
# Out:
#          id                                              title  \
# 0     17283  House Republicans Fret About Winning Their Hea...
# 1     17284  Rift Between Officers and Residents as Killing...
# 2     17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3     17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4     17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...     ...                                                ...
# 7798  26533  U.N. Relief Official Calls Crisis in Aleppo th...
# 7799  26534  Federal Judge Curbs Enforcement of North Carol...
# 7800  26536  Mexicans Accuse President of ‘Historic Error’ ...
# 7801  26537  U.S. Presses for Truce in Syria, With Its Larg...
# 7802  26538  Airbnb Adopts Rules to Fight Discrimination by...
#
#          publication                           author        date    year  \
# 0     New York Times                       Carl Hulse  2016-12-31  2016.0
# ...

# %%
n[n.content.str.contains('Phoenix')]
# Exact match for Phoenix
# Out:
#           id                                              title  \
# 119    17420  Recovery Finally Yields Big Gains for Average ...
# 139    17444  Trump Insists Mexico Will Pay for Wall After U...
# 483    17832  Women’s March Highlights as Huge Crowds Protes...
# 488    17838  Trump’s Improvised Path to a Month of Executiv...
# 491    17841  Inauguration Protesters and Police Clash on Wa...
# ...      ...                                                ...
# 48501  71563  George Soros is going after ’America’s toughes...
# 48550  71624  Meet the man behind Right Side Broadcasting, t...
# 48971  72137  Michelle Obama torches Donald Trump: ’You do n...
# 49144  72348  Conservative law group sues Department of Just...
# 49684  73019  These maps show how Mexican cartels dominate t...
#
#             publication                                             author  \
# 119      New York Times                                 Nelson D. Schwartz
# ...

# %%
# Regex can help find more exact sources
n[n.content.str.contains(r'\D\d{5}\D', regex=True)]
# Out:
#           id                                              title  \
# 276    17594  In Iowa, Trump Voters Are Unfazed by Controver...
# 318    17638  I Know How It Feels to Be Someone’s ‘Token.’ I...
# 379    17712  Chelsea Manning Describes Bleak Life in a Men’...
# 603    17963  Review: In ‘Riverdale,’ Archie Is Hot and Haun...
# 1041   18464  Review: That ‘Sunset Boulevard’ Close-Up, Fine...
# ...      ...                                                ...
# 46586  69156  One of the first Tesla Model S cars ever built...
# 47088  69821  Marco Rubio’s account has been on fire since h...
# 47275  70059  The ’Never Trump’ movement has emerged from th...
# 47408  70221  Donald Trump is launching a website called Lyi...
# 48158  71146  New Snowden documents prove the hacked NSA fil...
#
#             publication            author        date    year  month  url  \
# 276      New York Times      Trip Gabriel  2017-01-19  2017.0    1.0  NaN
# ...

# %%
n.loc[48158].content
# Out:
# '’  ’ ’   Newly released documents from former US National Security Agency   contractor Edward Snowden confirm what many experts had already   believed:  and   implants that leaked online earlier this week is real. ’ ’   The key to confirming the leaked files, which was uploaded to   various   sites earlier this week by a group called   the ”Shadow Brokers,”  published on Friday by Sam   Biddle of The Intercept. It instructed NSA hackers on how to   track their malicious software by using a   string   buried in the code. ’ ’   The tracking string in the manual, ace02468bdf13579, also appears   inside code for a software implant called ”Second Date,” which   was leaked as part of the archive posted earlier this   week. ’ ’   But that’’s not the only piece of evidence that shows the leak   was, in essence, a software ”toolbox” for NSA hackers to   target adversaries. Among  are implants   Banana   Glee, Jet Plow, and Zesty Leak, which were all documented in   a     catalog of NSA tools
# ...

# %%
n[n.content.str.contains(r'\s\d{5}\D', regex=True)]
# Out:
#           id                                              title  \
# 276    17594  In Iowa, Trump Voters Are Unfazed by Controver...
# 318    17638  I Know How It Feels to Be Someone’s ‘Token.’ I...
# 379    17712  Chelsea Manning Describes Bleak Life in a Men’...
# 603    17963  Review: In ‘Riverdale,’ Archie Is Hot and Haun...
# 1041   18464  Review: That ‘Sunset Boulevard’ Close-Up, Fine...
# ...      ...                                                ...
# 45461  67748  The 2 most dangerous numbers in the universe a...
# 46586  69156  One of the first Tesla Model S cars ever built...
# 47088  69821  Marco Rubio’s account has been on fire since h...
# 47275  70059  The ’Never Trump’ movement has emerged from th...
# 47408  70221  Donald Trump is launching a website called Lyi...
#
#             publication            author        date    year  month  url  \
# 276      New York Times      Trip Gabriel  2017-01-19  2017.0    1.0  NaN
# ...

# %%
n.loc[276].content
# Out:
# 'MONTICELLO, Iowa  —   The Table of Knowledge was delving into   Donald J. Trump’s plans to upend government, and marveling at how he had forced his fellow Republicans in the House to reverse themselves on gutting the Office of Congressional Ethics. “He’s getting responses things are happening,” Jerry Retzlaff, a retiree, said. “He got Congress to turn themselves around with one tweet. ” “There’s no secret the press doesn’t like him, and neither does a lot of the leadership,” he added. “And that’s because he’s planning on making a lot of changes. ” The eight men around a rectangular table, sipping coffee from a hodgepodge of mugs donated by customers, meet daily for breakfasts of French toast, eggs and bacon at Darrell’s diner, all while solving the world’s problems, hence their gathering’s nickname. Washington may be veering from one Trump   controversy to another: unproved reports of Russia’s holding embarrassing information against him, possible ethical conflicts, the donors and b
# ...

# %%
n.loc[n.publication=='New York Times', 'publication'] = 'New Pork Rinds'
# The data in these columns is mutable
n
# Out:
#           id                                              title  \
# 0      17283  House Republicans Fret About Winning Their Hea...
# 1      17284  Rift Between Officers and Residents as Killing...
# 2      17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...      ...                                                ...
# 49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999  73469                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# 0      New Pork Rinds                     Carl Hulse  2016-12-31  2016.0
# ...

# %%
# Out:
#           id                                              title  \
# 0      17283  House Republicans Fret About Winning Their Hea...
# 1      17284  Rift Between Officers and Residents as Killing...
# 2      17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...      ...                                                ...
# 49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999  73469                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# 0      New Pork Rinds                     Carl Hulse  2016-12-31  2016.0
# ...

# %%
n['content'].apply(len)
# Out:
# 0         5607
# 1        27834
# 2        14018
# 3        12274
# 4         4195
#          ...
# 49995     5784
# 49996     6116
# 49997    59561
# 49998     7177
# 49999     2045
# Name: content, Length: 50000, dtype: int64

# %%
len('Call me Ishmael'.split())
# Out:
# 3

# %%
n['content'].apply(len.split())
# apply only takes the function, not everything in the function
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 n['content'].apply(len.split())
#       2 # apply only takes the function, not everything in the function
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'split'

# %%
def wordcount(x):
    return len(x.split())

wordcount('Call me Ishmael')
# Out:
# 3

# %%
n['content'].apply(wordcount)
# Out:
# 0         884
# 1        4770
# 2        2389
# 3        2119
# 4         694
#          ...
# 49995     965
# 49996     992
# 49997    9639
# 49998    1170
# 49999     333
# Name: content, Length: 50000, dtype: int64

# %%
n['content'].apply(lambda x:len(x.split()))
# lambda allows us to feed into apply like a one-line function
# perfect for singl-use functions
# Out:
# 0         884
# 1        4770
# 2        2389
# 3        2119
# 4         694
#          ...
# 49995     965
# 49996     992
# 49997    9639
# 49998    1170
# 49999     333
# Name: content, Length: 50000, dtype: int64

# %%
# create the column for words
n['words'] = n['content'].apply(lambda x:len(x.split()))
n
# Out:
#           id                                              title  \
# 0      17283  House Republicans Fret About Winning Their Hea...
# 1      17284  Rift Between Officers and Residents as Killing...
# 2      17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3      17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4      17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...      ...                                                ...
# 49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999  73469                       The Milky Way’s Stolen Stars
#
#           publication                         author        date    year  \
# 0      New York Times                     Carl Hulse  2016-12-31  2016.0
# ...

# %%
n.to_csv ('newnews.csv')
