# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
customers = pd.read_csv('BankChurners.csv',index_col='CLIENTNUM')
customers.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  ...  Credit_Limit  \
# ...

# %%
customers.sort_index()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708082083  Existing Customer            45      F                3
# 708083283  Attrited Customer            58      M                0
# 708084558  Attrited Customer            46      M                3
# 708085458  Existing Customer            34      F                2
# 708086958  Existing Customer            49      F                2
# ...                      ...           ...    ...              ...
# 828288333  Existing Customer            50      M                0
# 828291858  Attrited Customer            38      M                3
# 828294933  Attrited Customer            49      F                3
# 828298908  Existing Customer            54      M                4
# 828343083  Existing Customer            43      F                4
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
customers.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 768805383  Existing Customer            45      M                3
# 818770008  Existing Customer            49      F                5
# 713982108  Existing Customer            51      M                3
# 769911858  Existing Customer            40      F                4
# 709106358  Existing Customer            40      M                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 768805383     High School        Married     $60K - $80K          Blue
# 818770008        Graduate         Single  Less than $40K          Blue
# 713982108        Graduate        Married    $80K - $120K          Blue
# 769911858     High School        Unknown  Less than $40K          Blue
# 709106358      Uneducated        Married     $60K - $80K          Blue
#
#            Months_on_book  Total_Relationship_Count  ...  Credit_Limit  \
# ...

# %%
# method to get the filter to stick
customers.sort_index(inplace=True)

# %%
customers.head()
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708082083  Existing Customer            45      F                3
# 708083283  Attrited Customer            58      M                0
# 708084558  Attrited Customer            46      M                3
# 708085458  Existing Customer            34      F                2
# 708086958  Existing Customer            49      F                2
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# 708082083     High School        Married  Less than $40K          Blue
# 708083283         Unknown         Single     $40K - $60K          Blue
# 708084558       Doctorate       Divorced    $80K - $120K          Blue
# 708085458      Uneducated         Single  Less than $40K          Blue
# 708086958      Uneducated        Married         Unknown          Blue
#
#            Months_on_book  Total_Relationship_Count  ...  Credit_Limit  \
# ...

# %%
type(customers)
# Out:
# pandas.core.frame.DataFrame

# %%
# two ways to select columns
# The "dot" way
gend = customers.Gender

# The "dictionary" way
gend = customers['Gender']

# %%
type(gend)
# Converting changes from dataframe to series, and you lose functionality
# A series is a unidimensional array indexed by the index you chose
# Consider it an array in Panda
# Out:
# pandas.core.series.Series

# %%
firstlines = customers.loc[708082083:708084558, 'Gender':'Education_Level']
type[firstlines]
# loc = location - select multiple lines or ranges in lists
# Note that Pandas is between = for range
# Out:
# type[          Gender  Dependent_count Education_Level
# CLIENTNUM
# 708082083      F                3     High School
# 708083283      M                0         Unknown
# 708084558      M                3       Doctorate]

# %%
phds = customers[customers.Education_Level=='Doctorate']
# Filter to only where customer education level is equal to doctorate

# %%
phds
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708084558  Attrited Customer            46      M                3
# 708153558  Existing Customer            46      M                5
# 708249708  Existing Customer            48      F                1
# 708291633  Existing Customer            33      F                2
# 708300483  Attrited Customer            66      F                0
# ...                      ...           ...    ...              ...
# 819202533  Existing Customer            57      M                1
# 819979458  Existing Customer            35      F                3
# 821889858  Attrited Customer            50      F                1
# 823624158  Existing Customer            53      F                2
# 824915208  Existing Customer            44      F                3
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
type(phds)
# Out:
# pandas.core.frame.DataFrame

# %%
youngphds = customers[(customers.Customer_Age<35) & (customers.Education_Level == 'Doctorate')]
youngphds
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708291633  Existing Customer            33      F                2
# 710929233  Existing Customer            33      F                2
# 712112733  Existing Customer            33      M                2
# 712620858  Existing Customer            34      F                4
# 715321983  Existing Customer            33      F                2
# 719623083  Existing Customer            33      F                1
# 719826333  Existing Customer            34      F                2
# 736893108  Existing Customer            33      F                2
# 779134458  Attrited Customer            33      F                1
# 780199233  Existing Customer            33      M                2
# 789050883  Existing Customer            33      F                2
# 789952158  Existing Customer            34      F                1
# 799731033  Existing Customer            34      F                2
# ...

# %%
# For "or" statements, use the pipe command "|"
# For "not" statements, use the tilda command "~"
saneppl = customers[~(customers.Education_Level=='Doctorate')]
saneppl
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708082083  Existing Customer            45      F                3
# 708083283  Attrited Customer            58      M                0
# 708085458  Existing Customer            34      F                2
# 708086958  Existing Customer            49      F                2
# 708095133  Existing Customer            43      M                4
# ...                      ...           ...    ...              ...
# 828288333  Existing Customer            50      M                0
# 828291858  Attrited Customer            38      M                3
# 828294933  Attrited Customer            49      F                3
# 828298908  Existing Customer            54      M                4
# 828343083  Existing Customer            43      F                4
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
saneppl.drop(828343083)
# drops last customer, but is not permanent. must use "inplace=True"
# saneppl.drop(828343083, inplace=True)
# Remove from saneppl, but will stay in the customer database
# Out:
#               Attrition_Flag  Customer_Age Gender  Dependent_count  \
# CLIENTNUM
# 708082083  Existing Customer            45      F                3
# 708083283  Attrited Customer            58      M                0
# 708085458  Existing Customer            34      F                2
# 708086958  Existing Customer            49      F                2
# 708095133  Existing Customer            43      M                4
# ...                      ...           ...    ...              ...
# 828285858  Existing Customer            41      F                3
# 828288333  Existing Customer            50      M                0
# 828291858  Attrited Customer            38      M                3
# 828294933  Attrited Customer            49      F                3
# 828298908  Existing Customer            54      M                4
#
#           Education_Level Marital_Status Income_Category Card_Category  \
# CLIENTNUM
# ...

# %%
customers.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_2'],
#       dtype='object')

# %%
customers.drop(customers.columns[21],axis=1,inplace=True)
# need axis = 1 because data frame has two axis

# %%
customers.columns
# Out:
# Index(['Attrition_Flag', 'Customer_Age', 'Gender', 'Dependent_count',
#        'Education_Level', 'Marital_Status', 'Income_Category', 'Card_Category',
#        'Months_on_book', 'Total_Relationship_Count', 'Months_Inactive_12_mon',
#        'Contacts_Count_12_mon', 'Credit_Limit', 'Total_Revolving_Bal',
#        'Avg_Open_To_Buy', 'Total_Amt_Chng_Q4_Q1', 'Total_Trans_Amt',
#        'Total_Trans_Ct', 'Total_Ct_Chng_Q4_Q1', 'Avg_Utilization_Ratio',
#        'Naive_Bayes_Classifier_Attrition_Flag_Card_Category_Contacts_Count_12_mon_Dependent_count_Education_Level_Months_Inactive_12_mon_1'],
#       dtype='object')
