# %%
import pandas as pd
n = pd.read_csv('newnews.csv')

# %%
n.sort_index()
# Out:
#        Unnamed: 0     id                                              title  \
# 0               0  17283  House Republicans Fret About Winning Their Hea...
# 1               1  17284  Rift Between Officers and Residents as Killing...
# 2               2  17285  Tyrus Wong, ‘Bambi’ Artist Thwarted by Racial ...
# 3               3  17286  Among Deaths in 2016, a Heavy Toll in Pop Musi...
# 4               4  17287  Kim Jong-un Says North Korea Is Preparing to T...
# ...           ...    ...                                                ...
# 49995       49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996       49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997       49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998       49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999       49999  73469                       The Milky Way’s Stolen Stars
#
# ...

# %%
n.sort_values(by='words')
# Out:
#        Unnamed: 0     id                                              title  \
# 42038       42038  63359  Enchanting waterfront murals painted while bal...
# 39869       39869  60381                            Wonders of the universe
# 40126       40126  60745                              The week in 32 photos
# 46859       46859  69511  Our favorite photos so far from the Giro d’Ita...
# 45125       45125  67326  A Marine who coaches Fortune 500 execs explain...
# ...           ...    ...                                                ...
# 1162         1162  18600  Full Transcript and Video: Trump News Conferen...
# 6407         6407  24673      The Great A.I. Awakening - The New York Times
# 7174         7174  25704                   The Fighter - The New York Times
# 22223       22223  40973  ***Horse Race LiveWire*** Nevada Votes: Trump ...
# 17533       17533  36274  ***Horse Race LiveWire*** 2 Days to South Caro...
#
# ...

# %%
n.sort_values(by='words', ascending=False)
# Out:
#        Unnamed: 0     id                                              title  \
# 17533       17533  36274  ***Horse Race LiveWire*** 2 Days to South Caro...
# 22223       22223  40973  ***Horse Race LiveWire*** Nevada Votes: Trump ...
# 7174         7174  25704                   The Fighter - The New York Times
# 6407         6407  24673      The Great A.I. Awakening - The New York Times
# 1162         1162  18600  Full Transcript and Video: Trump News Conferen...
# ...           ...    ...                                                ...
# 22175       22175  40925  Oakland ’Rave Cave’ Inferno: 9 Dead, 25 Missin...
# 21751       21751  40501  ITT Tech Shuts Down Campuses After Federal Cra...
# 40126       40126  60745                              The week in 32 photos
# 42038       42038  63359  Enchanting waterfront murals painted while bal...
# 39869       39869  60381                            Wonders of the universe
#
# ...

# %%
n.sort_values(by=['publication', 'words'], ascending=False)
# Out:
#        Unnamed: 0     id                                              title  \
# 7174         7174  25704                   The Fighter - The New York Times
# 6407         6407  24673      The Great A.I. Awakening - The New York Times
# 1162         1162  18600  Full Transcript and Video: Trump News Conferen...
# 6262         6262  24476  Donald Trump’s New York Times Interview: Full ...
# 6605         6605  24930  Choosing a School for My Daughter in a Segrega...
# ...           ...    ...                                                ...
# 49976       49976  73446  The U.S. Supreme Court Puts North Carolina’s 2...
# 49983       49983  73453  ‘We Have a Problem’: John Kerry on Making Poli...
# 49902       49902  73317                   The Atlanticâ€™s Week in Culture
# 49971       49971  73441  Michael Cohen: ’It Is Fake News Meant to Malig...
# 49999       49999  73469                       The Milky Way’s Stolen Stars
#
# ...

# %%
n.sort_values(by=['publication', 'words'], ascending=[True, False])
# Ascending can be prioritized by sort values order (publication = true, words = false)
# Out:
#        Unnamed: 0     id                                              title  \
# 49997       49997  73467  Trump Announces Plan That Does Little to Resol...
# 49863       49863  73272  Donald Trump’s Interests vs. America’s, Dubai ...
# 49984       49984  73454           The Enduring Mystery of Pain Measurement
# 49947       49947  73396  Inside LAX’s New Anti-Terrorism Intelligence Unit
# 49939       49939  73378                   The Donald Trump Cabinet Tracker
# ...           ...    ...                                                ...
# 6427         6427  24698  The Lives They Loved: Submit Your Memories - T...
# 3059         3059  20673  Reaction to a Supreme Court Tie on Immigration...
# 3108         3108  20727  Reactions to the Supreme Court Ruling on Texas...
# 5105         5105  22957      Voyeur | Christmas Trees - The New York Times
# 3823         3823  21527  When I’m Mistakenly Put on an Email Chain, Sho...
#
# ...

# %%
n.publication.value_counts()
# Out:
# Breitbart           23781
# CNN                 11488
# New York Times       7803
# Business Insider     6757
# Atlantic              171
# Name: publication, dtype: int64

# %%
npub = n.groupby('publication')

# %%
type(npub)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
npub.get_group('Atlantic')
# Andvantage of this is to do more things than just filter by a variable
# Out:
#        Unnamed: 0     id                                              title  \
# 49829       49829  73206  Obama: Reaching Out to Adversaries, Alienating...
# 49830       49830  73207  George Michael and Carrie Fisher: The Week in ...
# 49831       49831  73208                                 The New Reality TV
# 49832       49832  73209           5 Numbers That Explain Education in 2016
# 49833       49833  73210  The Atlantic  Politics & Policy Daily: Happy G...
# ...           ...    ...                                                ...
# 49995       49995  73465   Rex Tillerson Says Climate Change Is Real, but …
# 49996       49996  73466  The Biggest Intelligence Questions Raised by t...
# 49997       49997  73467  Trump Announces Plan That Does Little to Resol...
# 49998       49998  73468    Dozens of For-Profit Colleges Could Soon Close
# 49999       49999  73469                       The Milky Way’s Stolen Stars
#
# ...

# %%
npub.year.value_counts()
# can get the pieces of each varialbe
# Out:
# publication       year
# Atlantic          2017.0      148
#                   2016.0       23
# Breitbart         2016.0    16100
#                   2017.0     7606
#                   2015.0       72
#                   2013.0        2
#                   2014.0        1
# Business Insider  2016.0     4596
#                   2017.0     2161
# CNN               2016.0     4104
#                   2017.0     3822
#                   2015.0     3251
#                   2013.0      210
#                   2014.0       74
#                   2012.0       26
#                   2011.0        1
# New York Times    2017.0     4171
#                   2016.0     3628
#                   2015.0        3
#                   2014.0        1
# Name: year, dtype: int64

# %%
npub.year.value_counts(normalize = True)
# Out:
# publication       year
# Atlantic          2017.0    0.865497
#                   2016.0    0.134503
# Breitbart         2016.0    0.677011
#                   2017.0    0.319835
#                   2015.0    0.003028
#                   2013.0    0.000084
#                   2014.0    0.000042
# Business Insider  2016.0    0.680184
#                   2017.0    0.319816
# CNN               2016.0    0.357242
#                   2017.0    0.332695
#                   2015.0    0.282991
#                   2013.0    0.018280
#                   2014.0    0.006442
#                   2012.0    0.002263
#                   2011.0    0.000087
# New York Times    2017.0    0.534538
#                   2016.0    0.464949
#                   2015.0    0.000384
#                   2014.0    0.000128
# Name: year, dtype: float64

# %%
npub.author.value_counts()
# Out:
# publication     author
# Atlantic        David A. Graham                                                                                   12
#                 David Sims                                                                                         8
#                 Russell Berman                                                                                     8
#                 Candice Norwood                                                                                    7
#                 Conor Friedersdorf                                                                                 7
#                                                                                                                   ..
# New York Times  Zachary Woolfe, Anthony Tommasini, Michael Cooper, Corinna da Fonseca-Wollheim and David Allen     1
#                 Zahra Nader and Mujib Mashal                                                                       1
# ...

# %%
npub.words.describe()
# Out:
#                     count         mean          std    min    25%     50%  \
# publication
# Atlantic            171.0  1379.315789  1128.407621  333.0  829.0  1118.0
# Breitbart         23781.0   497.874480   604.773366    1.0  239.0   371.0
# Business Insider   6757.0   449.594939   497.417263    1.0  182.0   321.0
# CNN               11488.0   707.058409   517.114599    0.0  370.0   610.5
# New York Times     7803.0  1162.046649   783.609130    1.0  785.0  1074.0
#
#                      75%      max
# publication
# Atlantic          1466.5   9639.0
# Breitbart          573.0  25519.0
# Business Insider   552.0   8465.0
# CNN                922.0  13863.0
# New York Times    1328.0  17115.0

# %%
npub.words.agg(['median', 'mean'])
# Out:
#                   median         mean
# publication
# Atlantic          1118.0  1379.315789
# Breitbart          371.0   497.874480
# Business Insider   321.0   449.594939
# CNN                610.5   707.058409
# New York Times    1074.0  1162.046649

# %%
npub.words.median()
# Out:
# publication
# Atlantic            1118.0
# Breitbart            371.0
# Business Insider     321.0
# CNN                  610.5
# New York Times      1074.0
# Name: words, dtype: float64

# %%
n.words.median()
# Out:
# 476.0

# %%
npub.words.median().sort_values(ascending = False).plot.bar()
# Out:
# <AxesSubplot: xlabel='publication'>
