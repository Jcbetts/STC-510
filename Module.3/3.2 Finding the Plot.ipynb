# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
f = np.loadtxt('grades.txt',delimiter=',')

# %%
plot(f.T[1],f.T[2])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [19], line 1
# ----> 1 plot(f.T[1],f.T[2])
#       2 plt.show()
#
# NameError: name 'plot' is not defined

# %%
plt.scatter(f.T[1],f.T[2])
plt.show()

# %%
plt.plot(f.T)
plt.show()

# %%
plt.ylim(bottom=10, top=60)
plt.xticks([0,1,2])
plt.xlabel('Tests')
plt.plot(f.T)
plt.show()
